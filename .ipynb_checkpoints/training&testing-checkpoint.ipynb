# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('carprices.csv')
X=df.drop(['Car Model','Sell Price($)'],axis='columns')
X
y=df['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 3     22500         2
# 8     91000         8
# 7     72000         6
# 6     52000         5
# 1     35000         3
# 10    83000         7
# 12    59000         5
# 2     57000         5

# %%
X_test.shape
# Out:
# (4, 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([26385.93981048, 23416.097053  , 31560.57273769, 18682.42215974])

# %%
y_test
# Out:
# 5     29400
# 9     22000
# 4     31500
# 11    21000
# Name: Sell Price($), dtype: int64

# %%
model.score(X_test,y_test)
# Out:
# 0.8011686647730172
